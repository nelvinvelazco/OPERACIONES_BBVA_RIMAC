# %%
import pandas as pd
import os
import numpy as np
from datetime import datetime
from zoneinfo import ZoneInfo
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
pd.set_option('display.max_columns', None)

# %%
df_desgravamen= pd.read_csv("C:/datos/reporte errores tc.csv", encoding='latin1', sep=';',dtype={'CERTIFICADO': str, 
                                                                                                       'CODIGO_ERROR': str})
# Out:
# C:\Users\xt11442\AppData\Local\Temp\ipykernel_26832\2786429416.py:1: DtypeWarning: Columns (0: TIPO_MOVIMIENTO, 1: ORIGEN_ERROR, 2: DESCRIPCION_ERROR, 3: OBSERVACION, 4: MONEDA) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_desgravamen= pd.read_csv("C:/datos/reporte errores tc.csv", encoding='latin1', sep=';',dtype={'CERTIFICADO': str,

# %%
df_desgravamen['CERTIFICADO'] = df_desgravamen["CERTIFICADO"].str[1:]

# %%
df_desgravamen['CODIGO_ERROR'] = df_desgravamen['CODIGO_ERROR'].apply(lambda x: str(x).zfill(4) if pd.notnull(x) else "")

# %%
df_desgravamen.head(3)
# Out:
#             CERTIFICADO TIPO_MOVIMIENTO ORIGEN_ERROR CODIGO_ERROR  \
# 0  00110199734000750564      Renovacion  Error Rimac         0177
# 1  00110199734000750564      Renovacion  Error Rimac         0177
# 2  00110199734000750564      Renovacion  Error Rimac         0177
#
#                                    DESCRIPCION_ERROR        OBSERVACION  \
# 0  [**ERROR**]La p¿a no fue procesada por el proc...  INSERTAR VIGENCIA
# 1  [**ERROR**]La p¿a no fue procesada por el proc...  INSERTAR VIGENCIA
# 2  [**ERROR**]La p¿a no fue procesada por el proc...  INSERTAR VIGENCIA
#
#   MONEDA  PRIMA_BRUTA
# 0    SOL        61.44
# 1    SOL        61.44
# 2    SOL        61.44

# %%
df_desgravamen['CODIGO_ERROR'].value_counts()
# Out:
# CODIGO_ERROR
# 0177    205700
# 0199     51851
# 1143     48173
# 1157     22344
# 1152     18565
# 2007     16726
# 1124      7097
# 0163      3290
# 0117      2736
# 0259      1503
# 0852       987
# 0011       501
# 1140       386
# 0119       260
# 9993       192
# 7460       184
# 0037       133
# 1096       129
# 2395       123
# 0317        30
# 1057        24
# 0941        15
# 0034        12
# 1134        10
# 0306        10
# 0159         7
# 9994         5
# 0050         5
# 9979         5
# 1167         4
# 0061         3
# 1131         1
# 1150         1
# 0141         1
# 0005         1
# 0010         1
# Name: count, dtype: int64

# %%
df_desgravamen.to_csv(
    "C:/datos/reporte_errores_prestamos_utf8.csv",
    encoding="utf-8", index=False)

# %%
schema_desgravamen = [
        bigquery.SchemaField("CERTIFICADO", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("TIPO_MOVIMIENTO", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("ORIGEN_ERROR", bigquery.enums.SqlTypeNames.DATE),
        bigquery.SchemaField("CODIGO_ERROR", bigquery.enums.SqlTypeNames.INTEGER),
        bigquery.SchemaField("DESCRIPCION_ERROR", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("OBSERVACION", bigquery.enums.SqlTypeNames.INTEGER),
        bigquery.SchemaField("MONEDA", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("PRIMA_BRUTA", bigquery.enums.SqlTypeNames.FLOAT),
        
        ]

# %%
df_desgravamen.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 971018 entries, 0 to 971017
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CERTIFICADO        381015 non-null  str
#  1   TIPO_MOVIMIENTO    381015 non-null  str
#  2   ORIGEN_ERROR       381015 non-null  str
#  3   CODIGO_ERROR       381015 non-null  str
#  4   DESCRIPCION_ERROR  381015 non-null  str
#  5   OBSERVACION        314453 non-null  str
#  6   MONEDA             381015 non-null  str
#  7   PRIMA_BRUTA        971018 non-null  float64
# dtypes: float64(1), str(7)
# memory usage: 59.3 MB
