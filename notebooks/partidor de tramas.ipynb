# %%
from tkinter import Tk, StringVar, BooleanVar, END
from tkinter import filedialog, messagebox, Label, Frame, Button, Checkbutton, Text, font, Entry
import re
import os
from datetime import datetime


def limpiar_linea(linea: str) -> str:
    linea= re.sub(r'[^\x20-\x7E\n\r]|\t', ' ', linea)
    return linea


def agrupar_por_tipo(archivo_entrada):
    grupos = {}
    limpiar_trama = var_check.get()
    with open(archivo_entrada, 'r', encoding='latin-1', errors='ignore') as file_txt:
        for linea in file_txt:
            linea_trama= linea
            if limpiar_trama:
                linea_trama = limpiar_linea(linea)
            tipo = linea_trama[:3]
            if (tipo == '803') & (linea_trama[639:641]!= '01'):
                tipo= '803_TLMK'
            if tipo not in grupos:
                grupos[tipo] = []
            grupos[tipo].append(linea_trama)
    return grupos


def guardar_por_tipo(grupos, destino):
    os.makedirs(destino, exist_ok=True)
    for tipo, lineas in grupos.items():
        ruta_salida = os.path.join(destino, f"prod_{tipo}.txt")
        escribir_log(f"📦 Producto {tipo}: ({len(lineas)} registros)")
        with open(ruta_salida, 'w', encoding='utf-8') as f:
            for linea in lineas:
                f.write(linea)
        escribir_log(f"✅ Producto {tipo} guardado en: {ruta_salida}")


def seleccionar_archivo():
    ruta = filedialog.askopenfilename(
        title="Selecciona el archivo",
        filetypes=[("Archivos de texto", "*.txt")]
    )
    if ruta:
        ruta_archivo.set(ruta)
    return

def seleccionar_destino():
    ruta = filedialog.askdirectory(
        title="Selecciona carpeta destino"
    )
    if ruta:
        ruta_destino.set(ruta)
    return


def escribir_log(mensaje):
    text_log.config(state="normal")
    text_log.insert(END, mensaje + "\n")
    text_log.config(state="disabled")
    text_log.see(END)
    ventana.update()
    return


def procesar_archivo():
    ruta = ruta_archivo.get()
    destino = ruta_destino.get()
    file_name = os.path.basename(ruta)
    destino = f"{destino}\{file_name} - {fecha_hora}"
    if not ruta:
        messagebox.showwarning("Advertencia", "Debes seleccionar un archivo", parent= ventana)
        return
    escribir_log("⏳ Leyendo archivo ...")
    grupos = agrupar_por_tipo(ruta)
    escribir_log(f"✅ Se encontraron {len(grupos)} Productos distintos")
    escribir_log("💾 Guardando archivos...")
    guardar_por_tipo(grupos, destino)
    escribir_log("🎉 Proceso finalizado")
    return

ventana = Tk()


default_font = font.nametofont("TkDefaultFont")
default_font.configure(size=10)
ventana.option_add("*Font", default_font)


ventana.title("Partidor de tramas")
ventana.geometry("600x400")  # ancho x alto
ventana.resizable(False, False)

ruta_archivo= StringVar()
ruta_destino = StringVar(value="C:/TRAMAS/")
var_check = BooleanVar(value=True) 
fecha_hora = datetime.now().strftime("%Y-%m-%d_%H%M%S")


label = Label(ventana, text="Seleccione el archivo trama (.txt)")
label.pack(side="top", anchor="w", padx=10, pady=3)

frame_boton_y_check = Frame(ventana)
frame_boton_y_check.pack(anchor="w", padx=10, pady=5)

boton_selec = Button(frame_boton_y_check, text="CARGAR ARCHIVO", command=seleccionar_archivo)
boton_selec.pack(side="left")

check_limpieza = Checkbutton(frame_boton_y_check, text="Limpiar Tramas", variable=var_check)
check_limpieza.pack(side="left", padx=30)

frame_archivo = Frame(ventana)
frame_archivo.pack(anchor="w", padx=10, pady=1)

label_Archivo = Label(frame_archivo, text="Archivo:")
label_Archivo.pack(side="left")

label_ruta = Label(frame_archivo, textvariable=ruta_archivo)
label_ruta.pack(side="left", padx=5, )

text_log = Text(ventana, bg="black", fg="white", font=("Consolas", 10), height=17, width=85)
text_log.pack(side="top", anchor="w", padx=10, pady=1)

frame_boton_procesar = Frame(ventana)
frame_boton_procesar.pack(anchor="w", padx=10, pady=5)

boton_procesar = Button(frame_boton_procesar, text="PROCESAR ARCHIVO", command=procesar_archivo)
boton_procesar.pack(side="left")

frame_destino = Frame(frame_boton_procesar)
frame_destino.pack(anchor="w", padx=30)

label_destino = Label(frame_destino, text="Destino:")
label_destino.pack(side="left", padx=1)

entry_destino = Entry(frame_destino, textvariable=ruta_destino, width=40, 
                    state="readonly", readonlybackground="white", relief="flat")
entry_destino.pack(side="left", padx=5)

Boton_destino = Button(frame_destino, text="...", command=seleccionar_destino)
Boton_destino.pack(side="left", padx=5)


ventana.mainloop()

# %%
import re

def limpiar_trama(texto: str) -> str:
    return re.sub(r'[^\x20-\x7E\n\r]|\t', ' ', texto)


texto = "Hola\tmundo\x01 ñáé\nNueva línea\rFin"

limpio = limpiar_trama(texto)

print(limpio)
# Out:
# Hola mundo
# Finva l nea

# %%
archivo= "C:\DATOS\TRAMA 23-06-26.TXT"

# %%
def limpiar_linea(linea: str) -> str:
    linea= re.sub(r'[^\x20-\x7E\n\r]|\t', ' ', linea)
    return linea

# %%
with open(archivo, 'r', encoding='latin-1', errors='ignore') as file_txt:
    for linea in file_txt:
        linea_limpia = limpiar_linea(linea)
            
        for i, c in enumerate(linea_limpia):
            if ord(c) == 65279:
                print(f"Pos {i}: BOM encontrado")

# %%
def limpiar_linea(linea: str) -> str:
    linea= re.sub(r'[^\x20-\x7E\n\r]|\t', ' ', linea)
    return linea

def agrupar_por_tipo(archivo_entrada):
    grupos = {}
    with open(archivo_entrada, 'r', encoding='latin-1', errors='ignore') as file_txt:
        for linea in file_txt:
            linea_limpia = limpiar_linea(linea)
        
            tipo = linea_limpia[:3]
            if (tipo == '803') & (linea_limpia[639:641] != '01'):
                tipo= '803_TLMK'
            if tipo not in grupos:
                grupos[tipo] = []
            grupos[tipo].append(linea_limpia)
    return grupos

# %%
with open(archivo, 'r', encoding='latin-1', errors='ignore') as file_txt:
    for linea in file_txt:
        linea_limpia = limpiar_linea(linea)
        for i, c in enumerate(linea):
            if c.isspace() and c != ' ' and c not in ['\n', '\r']:
                print(f"Pos {i}: {repr(c)} - Unicode {ord(c)}")
# Out:
# Pos 274: '\xa0' - Unicode 160
# Pos 269: '\xa0' - Unicode 160
# Pos 219: '\xa0' - Unicode 160
# Pos 277: '\xa0' - Unicode 160
# Pos 277: '\xa0' - Unicode 160
# Pos 277: '\xa0' - Unicode 160
# Pos 276: '\xa0' - Unicode 160
# Pos 268: '\xa0' - Unicode 160
# Pos 274: '\xa0' - Unicode 160
# Pos 271: '\t' - Unicode 9
# Pos 268: '\xa0' - Unicode 160
# Pos 269: '\xa0' - Unicode 160
# Pos 272: '\xa0' - Unicode 160
# Pos 273: '\xa0' - Unicode 160
# Pos 277: '\xa0' - Unicode 160

# %%
grupos = agrupar_por_tipo(archivo)

for tipo, lineas in grupos.items():
    print(f"Tipo {tipo}: {len(lineas)} registros")
# Out:
# Tipo 703: 24 registros
# Tipo 803_TLMK: 998 registros
# Tipo 804: 235 registros
# Tipo 815: 6 registros
# Tipo 816: 746 registros
# Tipo 818: 405 registros
# Tipo 825: 138 registros
# Tipo 829: 99 registros
# Tipo 901: 504 registros
# Tipo 902: 149 registros
# Tipo 903: 974 registros
# Tipo 904: 1691 registros
# Tipo 905: 43 registros
# Tipo 906: 38 registros
# Tipo 907: 87 registros
# Tipo 909: 4 registros
# Tipo 918: 435 registros
# Tipo 919: 6 registros
# Tipo 941: 4 registros
# Tipo 951: 4850 registros
# Tipo 952: 870 registros
# Tipo 953: 412 registros
# Tipo 954: 27 registros
# Tipo 958: 384 registros
# Tipo 959: 12 registros
# Tipo 961: 152 registros
# Tipo 962: 83 registros
# Tipo 963: 28 registros
# Tipo 964: 7 registros
# Tipo 966: 43 registros
# Tipo 968: 7 registros
# Tipo 972: 16 registros
# Tipo 201: 2 registros
# Tipo 250: 351 registros
# Tipo 251: 193 registros
# Tipo 252: 30 registros
# Tipo 254: 22 registros
# Tipo 800: 109 registros
# Tipo 803: 41 registros
# Tipo 808: 74 registros
# Tipo 812: 1527 registros
# Tipo 822: 126 registros
# Tipo 827: 73 registros

# %%
for lines in grupos['815']:
    print(lines)
# Out:
# 815001104652840012744940465                01PEN4VILLENA                       ZACARIAS                      SOFIA DONATA                  FS19700824L09604847  FRAY BARTOLOME DE LAS CASAS                                                                         LOS JARDINES                  265             SAN MARTIN DE PORRES          01L0031PERMAV.URB01031 956848596202606182026061820260718099I00000000060000{00000000000054I1030000000566000000060000{000000000054I0000{0000{0000{001103530502001307661044M                                                                                                                                      01
#
# 815001104652840012744940465                03PEN0000566   L09604847  PEN000000000054I20260618
#
# 815001104652840012745830465                01PEN4CANAYO                        QUININI                       RIDER                         MS19880720L46803211  LEON DE JUDA                                      POR EL HOSPEDAJE EL MAMEY                         CALLERIA                      MZ 29   LT 18   CALLERIA                      25     PERMJR.ZNA01001 973656416202606182026061820260718099I00000000060000{00000000000054I1030000000571000000060000{000000000054I0000{0000{0000{001101955202006229111026M                                                                                                                                      01
#
# 815001104652840012745830465                03PEN0000571   L46803211  PEN000000000054I20260618
#
# 815001104652040013882440465                01PEN4PAUCAR                        HUAYTA                        POLICARPIO                    MS19850323L42992225  NA                                                ALTURA DEL MERCADO       ZON DE JESUS             JUAN VELASCO ALAVAR           MZ H    LT 17   CAYMA                         06     PERMCALPJJ01003 949413261202606182026061820260718099I00000000060000{00000000000054I1030000000736000000060000{000000000054I0000{0000{0000{001102268802002447521030M                                                                                                                                      01
#
# 815001104652040013882440465                03PEN0000736   L42992225  PEN000000000054I20260618

# %%
import re
import os
from datetime import datetime

archivo= "C:\DATOS\RED110626_1206.TXT"
fecha_hora = datetime.now().strftime("%Y-%m-%d_%H%M%S")
destino = f"C:\DATOS\TRAMAS_{fecha_hora}"

def limpiar_linea(linea: str) -> str:
    return re.sub(r'[^\x20-\x7E\n\r]|\t', ' ', linea)


def agrupar_por_tipo(archivo_entrada):
    grupos = {}

    with open(archivo_entrada, 'r', encoding='latin-1', errors='ignore') as file_txt:
        for linea in file_txt:
            linea_limpia = limpiar_linea(linea)
            tipo = linea_limpia[:3]
            if tipo not in grupos:
                grupos[tipo] = []
            grupos[tipo].append(linea_limpia)

    return grupos

def guardar_por_tipo(grupos, destino):
    os.makedirs(destino, exist_ok=True)

    for tipo, lineas in grupos.items():
        ruta_salida = os.path.join(destino, f"tipo_{tipo}.txt")
        print(f"📦 Guardando tipo {tipo}... ({len(lineas)} registros)")
        with open(ruta_salida, 'w', encoding='utf-8') as f:
            for linea in lineas:
                f.write(linea)
        print(f"✅ Tipo {tipo} guardado en: {ruta_salida}")


    
grupos = agrupar_por_tipo(archivo)
print(f"✅ Se encontraron {len(grupos)} tipos distintos")
print("💾 Guardando archivos...")
guardar_por_tipo(grupos, destino)

print("🎉 Proceso finalizado")
# Out:
# ✅ Se encontraron 41 tipos distintos
# 💾 Guardando archivos...
# 📦 Guardando tipo 703... (11 registros)
# ✅ Tipo 703 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_703.txt
# 📦 Guardando tipo 801... (3 registros)
# ✅ Tipo 801 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_801.txt
# 📦 Guardando tipo 803... (1165 registros)
# ✅ Tipo 803 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_803.txt
# 📦 Guardando tipo 804... (293 registros)
# ✅ Tipo 804 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_804.txt
# 📦 Guardando tipo 815... (2 registros)
# ✅ Tipo 815 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_815.txt
# 📦 Guardando tipo 816... (928 registros)
# ✅ Tipo 816 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_816.txt
# 📦 Guardando tipo 818... (418 registros)
# ✅ Tipo 818 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_818.txt
# 📦 Guardando tipo 825... (162 registros)
# ✅ Tipo 825 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_825.txt
# 📦 Guardando tipo 829... (101 registros)
# ✅ Tipo 829 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_829.txt
# 📦 Guardando tipo 901... (467 registros)
# ✅ Tipo 901 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_901.txt
# 📦 Guardando tipo 902... (91 registros)
# ✅ Tipo 902 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_902.txt
# 📦 Guardando tipo 903... (482 registros)
# ✅ Tipo 903 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_903.txt
# 📦 Guardando tipo 904... (919 registros)
# ✅ Tipo 904 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_904.txt
# 📦 Guardando tipo 905... (49 registros)
# ✅ Tipo 905 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_905.txt
# 📦 Guardando tipo 906... (15 registros)
# ✅ Tipo 906 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_906.txt
# 📦 Guardando tipo 907... (23 registros)
# ✅ Tipo 907 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_907.txt
# 📦 Guardando tipo 918... (1422307 registros)
# ✅ Tipo 918 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_918.txt
# 📦 Guardando tipo 919... (4706 registros)
# ✅ Tipo 919 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_919.txt
# 📦 Guardando tipo 951... (5810 registros)
# ✅ Tipo 951 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_951.txt
# 📦 Guardando tipo 952... (733 registros)
# ✅ Tipo 952 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_952.txt
# 📦 Guardando tipo 953... (294 registros)
# ✅ Tipo 953 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_953.txt
# 📦 Guardando tipo 954... (14 registros)
# ✅ Tipo 954 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_954.txt
# 📦 Guardando tipo 958... (321 registros)
# ✅ Tipo 958 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_958.txt
# 📦 Guardando tipo 959... (2 registros)
# ✅ Tipo 959 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_959.txt
# 📦 Guardando tipo 961... (223 registros)
# ✅ Tipo 961 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_961.txt
# 📦 Guardando tipo 962... (86 registros)
# ✅ Tipo 962 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_962.txt
# 📦 Guardando tipo 963... (21 registros)
# ✅ Tipo 963 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_963.txt
# 📦 Guardando tipo 964... (3 registros)
# ✅ Tipo 964 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_964.txt
# 📦 Guardando tipo 966... (35 registros)
# ✅ Tipo 966 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_966.txt
# 📦 Guardando tipo 968... (10 registros)
# ✅ Tipo 968 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_968.txt
# 📦 Guardando tipo 972... (14 registros)
# ✅ Tipo 972 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_972.txt
# 📦 Guardando tipo 201... (2 registros)
# ✅ Tipo 201 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_201.txt
# 📦 Guardando tipo 250... (306 registros)
# ✅ Tipo 250 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_250.txt
# 📦 Guardando tipo 251... (183 registros)
# ✅ Tipo 251 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_251.txt
# 📦 Guardando tipo 252... (21 registros)
# ✅ Tipo 252 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_252.txt
# 📦 Guardando tipo 254... (15 registros)
# ✅ Tipo 254 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_254.txt
# 📦 Guardando tipo 800... (106 registros)
# ✅ Tipo 800 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_800.txt
# 📦 Guardando tipo 808... (84 registros)
# ✅ Tipo 808 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_808.txt
# 📦 Guardando tipo 812... (1657 registros)
# ✅ Tipo 812 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_812.txt
# 📦 Guardando tipo 822... (144 registros)
# ✅ Tipo 822 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_822.txt
# 📦 Guardando tipo 827... (106 registros)
# ✅ Tipo 827 guardado en: C:\DATOS\TRAMAS_2026-06-18_181013\tipo_827.txt
# 🎉 Proceso finalizado
