# %%
import pandas as pd
from datetime import datetime
import pytz
import time
from io import BytesIO
import numpy as np
import os
pd.set_option('display.max_columns', None)

# %%
#df_datos= pd.read_excel("C:\DATOS\MEMOS\CUADRO_FCR1_NACAR_BBVA_2024-2026.xlsx", sheet_name=0, dtype=str)
#df_datos= pd.read_excel("C:\DATOS\MEMOS\CUADRO_FCR2_PRORRATA_BBVA_2026.xlsx", sheet_name=0, dtype=str)
df_datos= pd.read_excel("C:\DATOS\MEMOS\CUADRO_OBLIGACIONES_BBVA_2026.xlsx", sheet_name=0, dtype=str)
# Out:
# c:\Users\xt11442\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell F8636 is marked as a date but the serial value 19052600865 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\xt11442\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell F8661 is marked as a date but the serial value 18052600173 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\xt11442\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell F8662 is marked as a date but the serial value 18052600173 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)

# %%
df_datos.columns = (df_datos.columns.str.strip().str.upper().str.replace(r'[^A-Za-z0-9]', '_', regex=True))

# %%
df_datos= df_datos.rename(columns={'SITE':'ID', 'N__CORRELATIVO___REQUERIMIENTO':'ID', 'CASO_SF':'ID',
                                   'FECHA_DE_SOLICITUD_DE_OPERACIONES':'FECHA_SOLICITUD_OPER',
                                   'NRO_CERTIFICADO_BANCO':'CERTIFICADO_BANCO', 'MONTO_RECLAMADO_S__USD':'MONTO_RECLAMADO', 
                                   'MTO_LA':'MONTO_LA', 'F_EMISION_LA':'FECHA_EMISION_LA'})

# %%
df_datos= df_datos[['ID','FECHA_SOLICITUD_OPER','CERTIFICADO_BANCO','PRODUCTO','MONEDA','MONTO_RECLAMADO', 'NUMERO_LA',
                              'MONTO_LA', 'ESTADO_LA', 'FECHA_EMISION_LA', 'ESTADO_MEMOS']]

# %%
df_datos.head(3)
# Out:
#            ID FECHA_SOLICITUD_OPER     CERTIFICADO_BANCO            PRODUCTO  \
# 0  0027055041  2026-01-05 00:00:00  00110354824000294250  VEHICULAR OPTATIVO
# 1  0027055040  2026-01-05 00:00:00  00110716814000247004  SALUD A TU ALCANCE
# 2  0027055017  2026-01-05 00:00:00  00110333264000574828         HOGAR TOTAL
#
#   MONEDA MONTO_RECLAMADO  NUMERO_LA MONTO_LA ESTADO_LA     FECHA_EMISION_LA  \
# 0    USD          870.45  178316796   870.45       ACT  2026-01-08 00:00:00
# 1    SOL            1991  178375156  1990.97       ACT  2026-01-14 00:00:00
# 2    SOL          1553.8  178315151   1553.8       ACT  2026-01-08 00:00:00
#
#   ESTADO_MEMOS
# 0    CONCLUIDO
# 1    CONCLUIDO
# 2    CONCLUIDO
